# %% [markdown]
# # pre-process the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
train_df = pd.read_csv('.\\dataset\\train.csv')
test_df = pd.read_csv('.\\dataset\\test.csv')

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.drop(['PassengerId','Name','Ticket','Cabin','Embarked'],axis='columns',inplace=True)

# %%
test_df.drop(['Name','Ticket','Cabin','Embarked'],axis='columns',inplace=True)

# %%
ids = test_df.pop('PassengerId')

# %%
ids
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %% [markdown]
# ## data processing
# now our data is ready to process

# %%
train_df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# dtype: object

# %%
train_df[train_df.Survived==0]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0           0       3    male  22.0      1      0   7.2500
# 4           0       3    male  35.0      0      0   8.0500
# 5           0       3    male   NaN      0      0   8.4583
# 6           0       1    male  54.0      0      0  51.8625
# 7           0       3    male   2.0      3      1  21.0750
# ..        ...     ...     ...   ...    ...    ...      ...
# 884         0       3    male  25.0      0      0   7.0500
# 885         0       3  female  39.0      0      5  29.1250
# 886         0       2    male  27.0      0      0  13.0000
# 888         0       3  female   NaN      1      2  23.4500
# 890         0       3    male  32.0      0      0   7.7500
#
# [549 rows x 7 columns]

# %%
pclass_survived_no = train_df[train_df.Survived==0].Pclass
pclass_survived_yes = train_df[train_df.Survived==1].Pclass

# %%
plt.xlabel('pclass')
plt.ylabel('number of people')
plt.title('survivability prediction visualization')

plt.hist([pclass_survived_no, pclass_survived_yes], color=['green','red'], label=['survived=yes','survived=no'])
plt.legend()

# %%
train_df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female   NaN      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
Sex_survived_no = train_df[train_df.Survived==0].Sex
Sex_survived_yes = train_df[train_df.Survived==1].Sex

# %%
plt.xlabel('sex')
plt.ylabel('number of people')
plt.title('survivability prediction visualization')

plt.hist([Sex_survived_no, Sex_survived_yes], color=['green','red'], label=['survived=yes','survived=no'])
plt.legend()

# %%
Age_survived_no = train_df[train_df.Survived==0].Age
Age_survived_yes = train_df[train_df.Survived==1].Age

# %%
plt.xlabel('Age')
plt.ylabel('number of people')
plt.title('survivability prediction visualization')

plt.hist([Age_survived_no, Age_survived_yes], color=['green','red'], label=['survived=yes','survived=no'])
plt.legend()

# %%
SibSp_survived_no = train_df[train_df.Survived==0].SibSp
SibSp_survived_yes = train_df[train_df.Survived==1].SibSp

# %%
plt.xlabel('SibSp')
plt.ylabel('number of people')
plt.title('survivability prediction visualization')

plt.hist([SibSp_survived_no, SibSp_survived_yes], color=['green','red'], label=['survived=yes','survived=no'])
plt.legend()

# %%
Parch_survived_no = train_df[train_df.Survived==0].Parch
Parch_survived_yes = train_df[train_df.Survived==1].Parch

# %%
plt.xlabel('Parch')
plt.ylabel('number of people')
plt.title('survivability prediction visualization')

plt.hist([Parch_survived_no, Parch_survived_yes], color=['green','red'], label=['survived=yes','survived=no'])
plt.legend()

# %% [markdown]
# as we can see there is no correlation between (sibsp,parch) and survivability so we drop them

# %%
test_df.drop(['SibSp','Parch'],axis='columns',inplace=True)
train_df.drop(['SibSp','Parch'],axis='columns',inplace=True)

# %%
train_df
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %% [markdown]
# #### handling string values

# %%
train_df['Sex'].replace({'female':1, 'male':0}, inplace=True)
test_df['Sex'].replace({'female':1, 'male':0}, inplace=True)

# %% [markdown]
# #### handling NaN values

# %%
for col in train_df:
    a = train_df[col].value_counts()
    b = train_df[col].isnull().sum()
    print(f'column:{col}: {a},\n null_sum = {b}')
# Out:
# column:Survived: Survived
# 0    549
# 1    342
# Name: count, dtype: int64,
#  null_sum = 0
# column:Pclass: Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64,
#  null_sum = 0
# column:Sex: Sex
# 0    577
# 1    314
# Name: count, dtype: int64,
#  null_sum = 0
# column:Age: Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64,
#  null_sum = 177
# column:Fare: Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: count, Length: 248, dtype: int64,
#  null_sum = 0

# %%
for col in test_df:
    a = test_df[col].value_counts()
    b = test_df[col].isnull().sum()
    print(f'column:{col}: {a},\n null_sum = {b}')
# Out:
# column:Pclass: Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64,
#  null_sum = 0
# column:Sex: Sex
# 0    266
# 1    152
# Name: count, dtype: int64,
#  null_sum = 0
# column:Age: Age
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 76.0     1
# 28.5     1
# 22.5     1
# 62.0     1
# 38.5     1
# Name: count, Length: 79, dtype: int64,
#  null_sum = 86
# column:Fare: Fare
# 7.7500     21
# 26.0000    19
# 13.0000    17
# 8.0500     17
# 7.8958     11
#            ..
# 7.8208      1
# 8.5167      1
# 78.8500     1
# 52.0000     1
# 22.3583     1
# Name: count, Length: 169, dtype: int64,
#  null_sum = 1

# %%
train_df.Age = train_df.Age.fillna(train_df.Age.median())
test_df.Age = test_df.Age.fillna(test_df.Age.median())

# %%
for col in train_df:
    b = train_df[col].isnull().sum()
    print(f'column:{col}: null_sum = {b}')
# Out:
# column:Survived: null_sum = 0
# column:Pclass: null_sum = 0
# column:Sex: null_sum = 0
# column:Age: null_sum = 0
# column:Fare: null_sum = 0

# %%
for col in test_df:
    b = test_df[col].isnull().sum()
    print(f'column:{col}:  null_sum = {b}')
# Out:
# column:Pclass:  null_sum = 0
# column:Sex:  null_sum = 0
# column:Age:  null_sum = 0
# column:Fare:  null_sum = 1

# %%
test_df.Fare = test_df.Fare.fillna(test_df.Fare.median())

# %%
train_df.Age = train_df.Age.apply(lambda x: int(round(x)))
test_df.Age = test_df.Age.apply(lambda x: int(round(x)))

# %%
train_df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex           int64
# Age           int64
# Fare        float64
# dtype: object

# %%
test_df.dtypes
# Out:
# Pclass      int64
# Sex         int64
# Age         int64
# Fare      float64
# dtype: object

# %% [markdown]
# ### outlier removal

# %%
#train_df[train_df.Age>(train_df.Age.mean()+3*train_df.Age.std())]

# %%
#train_df = train_df[train_df.Age<=(train_df.Age.mean()+3*train_df.Age.std())]

# %%
#train_df[train_df.Fare>(train_df.Fare.mean()+3*train_df.Fare.std())]

# %%
#train_df = train_df[train_df.Fare<=(train_df.Fare.mean()+3*train_df.Fare.std())]

# %%
#train_df

# %% [markdown]
# ## scale the data

# %%
cols_to_scale = ['Pclass', 'Age', 'Fare']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

train_df[cols_to_scale] = scaler.fit_transform(train_df[cols_to_scale])
test_df[cols_to_scale] = scaler.fit_transform(test_df[cols_to_scale])

# %% [markdown]
# #### spliting train dataset

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x = train_df.drop('Survived', axis='columns')
y = train_df['Survived']

# %%
x_train, x_test, y_train, y_test = tts(x, y, test_size=0.2, random_state=5)

# %% [markdown]
# #### Train using stand alone model

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

scores = cross_val_score(DecisionTreeClassifier(), x, y, cv=5)
scores
# Out:
# array([0.73184358, 0.76404494, 0.80898876, 0.79213483, 0.82022472])

# %%
scores.mean()
# Out:
# 0.7834473667691921

# %% [markdown]
# #### Train using Bagging

# %%
from sklearn.ensemble import BaggingClassifier

bag_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(), 
    n_estimators=100, 
    max_samples=0.8, 
    oob_score=True,
    random_state=0
)
bag_model.fit(x_train, y_train)
bag_model.oob_score_
# Out:
# 0.8061797752808989

# %%
bag_model.score(x_test, y_test)
# Out:
# 0.8268156424581006

# %%
bag_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(), 
    n_estimators=100, 
    max_samples=0.8, 
    oob_score=True,
    random_state=0
)
scores = cross_val_score(bag_model, x, y, cv=5)
scores
# Out:
# array([0.77094972, 0.80898876, 0.84831461, 0.78089888, 0.84269663])

# %%
scores.mean()
# Out:
# 0.810369719414977

# %% [markdown]
# #### میتونیم ببینیم که با استفاده از بگینگ دقت مدل بالا رفت

# %%
from sklearn.ensemble import RandomForestClassifier

scores = cross_val_score(RandomForestClassifier(n_estimators=50), x, y, cv=5)
scores.mean()
# Out:
# 0.813740505931831

# %% [markdown]
# ## use grid search cv to find best model

# %%
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear','sigmoid']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [20,40,60,100],
            'max_samples':[0.8, 0.6, 0.9]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(multi_class='auto'),
        'params': {
            'C': [1,5,10],
            'fit_intercept': [True,False],
            'solver': ['liblinear','lbfgs']
        }
    },
    'naive_bayes_gaussian': {
        'model': GaussianNB(),
        'params': {}
    },
    'naive_bayes_multinomial': {
        'model': MultinomialNB(),
        'params': {}
    },
    'decision_tree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ['gini','entropy', "log_loss"],
            'splitter': ['best', 'random']
        }
    },
    'adaboost': {
        'model': AdaBoostClassifier(),
        'params': {
            'n_estimators': [20,50,80,100],
            'learning_rate': [0.1,0.5,1.0]
        }
    },
    'gaussian_process': {
        'model': GaussianProcessClassifier(),
        'params': {}
    },
    'kn_class': {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [3,5, 9 ,13],
            'weights': ['uniform','distance'],
            
        }
    },
    'mlp': {
        'model': MLPClassifier(),
        'params': {
            'hidden_layer_sizes': [128,64],
            'learning_rate': ['constant','invscaling','adaptive'],
            'learning_rate_init': [0.01,0.001]
        }
    },
}

# %%
from sklearn.model_selection import GridSearchCV
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(x_train, y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\Users\chubbyshady\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\chubbyshady\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\chubbyshady\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ...

# %% [markdown]
# #### we can see random forest has the best score

# %%
model = RandomForestClassifier(n_estimators=40, max_samples=0.6)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_samples=0.6, n_estimators=40)

# %%
model.score(x_test,y_test)
# Out:
# 0.8547486033519553

# %%
y_predicted = model.predict(x_test)

# %% [markdown]
# ### confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[104,   7],
#        [ 19,  49]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# # imbalance SMOTE

# %% [markdown]
# now lets try smote to balance the dataset and see if score improves

# %%
x_smote = train_df.drop('Survived', axis='columns')
y_smote = train_df['Survived']

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(sampling_strategy='minority')

# %%
x_sm, y_sm = smote.fit_resample(x,y)

# %%
x_sm.shape
# Out:
# (1098, 4)

# %%
y_sm.shape
# Out:
# (1098,)

# %%
x_train_sm, x_test_sm, y_train_sm, y_test_sm = tts(x_sm, y_sm, test_size=0.2, random_state=5, stratify=y_sm)

# %%
scores = cross_val_score(DecisionTreeClassifier(), x_sm, y_sm, cv=5)
scores.mean()
# Out:
# 0.793362391033624

# %%
from sklearn.model_selection import GridSearchCV
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(x_train_sm, y_train_sm)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df_sm = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df_sm
# Out:
# C:\Users\chubbyshady\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\chubbyshady\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\chubbyshady\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ...

# %% [markdown]
# we can see score has improved a little bit

# %%
model_sm = RandomForestClassifier(n_estimators=40, max_samples=0.6)

# %%
model_sm.fit(x_train_sm,y_train_sm)
# Out:
# RandomForestClassifier(max_samples=0.6, n_estimators=40)

# %%
model.score(x_test_sm,y_test_sm)
# Out:
# 0.9

# %%
y_predicted = model.predict(x_test)

from sklearn.metrics import confusion_matrix
cm_sm = confusion_matrix(y_test, y_predicted)
cm_sm
# Out:
# array([[105,   5],
#        [ 17,  93]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm_sm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
final_pred = model_sm.predict(test_df)

# %%
output = pd.DataFrame({'PassengerId': ids,
                       'Survived': final_pred.squeeze()})

# %%
output
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
output.to_csv('submission.csv', index=False)
